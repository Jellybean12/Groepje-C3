# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline 
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://postgres:Welkom01!@10.30.1.10:5432/POC')

# %%
df= pd.read_sql("""
select *
from 
meting m
join 
satelliet s 
on m.sat_id=s.sat_id


""",engine)
# Out:
# ---------------------------------------------------------------------------
# UndefinedFunction                         Traceback (most recent call last)
# ~\Anaconda3.1\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1243                     self.dialect.do_execute(
# -> 1244                         cursor, statement, parameters, context
#    1245                     )
#
# ~\Anaconda3.1\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     551     def do_execute(self, cursor, statement, parameters, context=None):
# --> 552         cursor.execute(statement, parameters)
#     553
#
# UndefinedFunction: operator does not exist: character varying = integer
# LINE 7: on m.sat_id=s.sat_id
#                    ^
# HINT:  No operator matches the given name and argument types. You might need to add explicit type casts.
#
#
# ...

# %%
df
# Out:
#               id          pnt_id       datum  meting sat_id
# 0        2081411  L495951P138997  2018-07-20 -0.0083      5
# 1        2081412  L495951P138997  2018-08-13 -0.0061      5
# 2        2081413  L495951P138997  2018-09-06 -0.0050      5
# 3        2081414  L495951P138997  2018-09-30 -0.0025      5
# 4        2081415  L495951P138997  2018-10-24 -0.0048      5
# 5        2081416  L495951P138997  2018-11-17  0.0009      5
# 6        2081417  L495951P138997  2018-12-11 -0.0063      5
# 7        2081418  L496017P138896  2015-04-07  0.0000      5
# 8        2081419  L496017P138896  2015-05-01  0.0021      5
# 9        2081420  L496017P138896  2015-06-18 -0.0018      5
# 10       2081421  L496017P138896  2015-07-12  0.0030      5
# 11       2081422  L496017P138896  2015-08-05 -0.0004      5
# 12       2081423  L496017P138896  2015-08-29  0.0026      5
# 13       2081424  L496017P138896  2015-09-22  0.0130      5
# 14       2081425  L496017P138896  2015-10-16  0.0041      5
# ...
